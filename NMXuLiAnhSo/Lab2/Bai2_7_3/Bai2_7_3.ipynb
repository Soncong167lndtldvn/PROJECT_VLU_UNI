# %%
import numpy as np
import imageio.v2 as iio
import scipy.ndimage as sn
import matplotlib.pyplot as plt
img = iio.imread('bird.png')
gray = np.dot(img[..., :3], [0.299, 0.587, 0.114]).astype(np.uint8)
b = sn.maximum_filter(gray, size=5, mode='reflect')
print(b)
plt.imshow(b, cmap='gray')
plt.axis('off')
plt.show()
# Out:
# [[121 121 121 ... 138 138 138]
#  [128 128 128 ... 138 138 138]
#  [128 128 128 ... 138 138 138]
#  ...
#  [ 96  96  96 ...  83  83  83]
#  [ 96  96  96 ...  83  83  83]
#  [ 96  96  96 ...  83  83  83]]
