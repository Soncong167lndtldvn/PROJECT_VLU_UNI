# %%
import numpy as np
import imageio.v2 as iio
import scipy.ndimage as sn
import matplotlib.pyplot as plt
img = iio.imread('flower.jpeg')
gray = np.dot(img[..., :3], [0.299, 0.587, 0.114]).astype(np.uint8)
b = sn.minimum_filter(gray, size=5, mode='reflect')
print(b)
plt.imshow(b, cmap='gray')
plt.axis('off')
plt.show()
# Out:
# [[15 15 15 ... 53 53 66]
#  [15 15 15 ... 52 52 58]
#  [15 15 15 ... 52 52 58]
#  ...
#  [19 19 19 ... 31 31 37]
#  [19 19 19 ... 31 31 37]
#  [33 33 33 ... 31 31 39]]
